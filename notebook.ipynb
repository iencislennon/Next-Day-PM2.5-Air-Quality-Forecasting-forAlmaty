# %%
# %pip install matplotlib
# Out:
# ...
#
# [notice] A new release of pip is available: 26.0 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd 
import numpy as np
# pyrefly: ignore [missing-import]
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('/Users/ansartleubayev/Documents/20 projects /Almaty_PM2.5.csv')
df.head()
# Out:
#    value  coordinates  location_id                  location_name  \
# 0   37.5          NaN      3243331  Qapparov köşesı (akbota.info)
# 1   41.1          NaN      3243331  Qapparov köşesı (akbota.info)
# 2   24.9          NaN      3243331  Qapparov köşesı (akbota.info)
# 3   40.9          NaN      3243331  Qapparov köşesı (akbota.info)
# 4   70.4          NaN      3243331  Qapparov köşesı (akbota.info)
#
#    flagInfo.hasFlags  parameter.id parameter.name parameter.units  \
# 0              False             2           pm25           µg/m³
# 1              False             2           pm25           µg/m³
# 2              False             2           pm25           µg/m³
# 3              False             2           pm25           µg/m³
# 4              False             2           pm25           µg/m³
#
#    parameter.displayName period.label  ... coverage.expectedCount  \
# 0                    NaN         1day  ...                     24
# ...
